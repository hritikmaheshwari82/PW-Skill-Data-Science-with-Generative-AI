# %% [markdown]
# # Files, exceptional handling, logging and memory management Questions

# %% [markdown]
# **Q1. What is the difference between interpreted and compiled languages?**
#
# Interpreted Language: Executes code line by line (e.g., Python, JavaScript). Slower, easier to debug.
#
# Compiled Language: Translates the entire code into machine code before execution (e.g., C, C++). Faster, but needs recompilation after changes.
#
# **Q2. What is exception handling in Python?**
#
# Exception handling allows you to catch and manage runtime errors using try, except, else, and finally blocks, preventing the program from crashing.
#
# **Q3. What is the purpose of the finally block in exception handling?**
#
# The finally block executes no matter what, whether an exception occurs or not. It’s used for cleanup tasks like closing files or releasing resources.
#
# **Q4. What is logging in Python?**
#
# Logging records events that happen while a program runs. It helps track bugs, errors, and the program's flow using different log levels (DEBUG, INFO, WARNING, ERROR, CRITICAL).
#
# **Q5. What is the significance of the `__del__` method in Python?**
#
# The __del__ method is a destructor called when an object is about to be destroyed. It's used to release resources (like closing files or network connections).
#
# **Q6. What is the difference between `import` and `from ... import` in Python?**
#
# import module: Imports the entire module (e.g., import math).
#
# from module import name: Imports specific parts (e.g., from math import sqrt).
#
# **Q7. How can you handle multiple exceptions in Python?**
#
# You can handle multiple exceptions using:
#
# try:
#     # code
# except (TypeError, ValueError) as e:
#
#     print(e)
#
# Or use multiple except blocks:
#
# try:
#     # code
# except TypeError:
#
#     pass
# except ValueError:
#
#     pass
#
#
# **Q8. What is the purpose of the `with` statement when handling files in Python?**
#
# The with statement automatically manages file opening and closing, even if exceptions occur. It simplifies resource management.
#
# **Q9. What is the difference between multithreading and multiprocessing?**
#
# Multithreading: Runs multiple threads in one process. Good for I/O-bound tasks but limited by the Global Interpreter Lock (GIL).
#
# Multiprocessing: Runs multiple processes. Suitable for CPU-bound tasks and can use multiple cores.
#
# **Q10. What are the advantages of using logging in a program?**
#
# Tracks events and errors.
#
# Helps with debugging and monitoring.
#
# Allows different severity levels.
#
# Can log to files, consoles, or remote servers.
#
# Better than using print statements in production.
#
#
# **Q11. What is memory management in Python?**
#
# Memory management in Python refers to the efficient allocation, tracking, and releasing of memory used by Python programs. It includes:
#
# Automatic memory allocation
#
# Garbage collection
#
# Reference counting
#
# Managed by the Python memory manager
#
# **Q12. What are the basic steps involved in exception handling in Python?**
#
# try: Write the code that might raise an exception.
#
# except: Handle specific or general exceptions.
#
# else (optional): Runs if no exception occurs.
#
# finally (optional): Always runs, used for cleanup.
#
# **Q13. Why is memory management important in Python?**
#
# Prevents memory leaks
#
# Ensures efficient use of system resources
#
# Maintains program stability and performance
#
# Automatically clears unused objects via garbage collection
#
# **Q14. What is the role of `try` and `except` in exception handling?**
#
# try: Wraps code that may raise exceptions.
#
# except: Catches and handles the exception gracefully without crashing the program.
#
# **Q15. How does Python's garbage collection system work?**
#
# Python uses:
#
# Reference counting: Each object tracks how many references point to it.
#
# Garbage collector (in gc module): Detects and cleans up objects involved in circular references that reference counting alone can't handle.
#
# **Q16. What is the purpose of the `else` block in exception handling?**
#
# The else block runs only if no exception occurs in the try block. It's used for code that should only execute when everything went smoothly.
#
# **Q17. What are the common logging levels in Python?**
#
# From lowest to highest severity:
#
# DEBUG – Detailed information for diagnosing problems
#
# INFO – General updates on program progress
#
# WARNING – Something unexpected but not breaking
#
# ERROR – A serious problem, program still runs
#
# CRITICAL – A very serious error, program may not continue
#
# **Q18. What is the difference between `os.fork()` and `multiprocessing` in Python?**
#
# os.fork():
#
# Unix/Linux only
#
# Low-level system call to create a child process
#
# Not cross-platform and harder to manage
#
# multiprocessing:
#
# Cross-platform (Windows, macOS, Linux)
#
# High-level module for creating and managing processes
#
# Safer and easier than fork()
#
# **Q19. What is the importance of closing a file in Python?**
#
# Ensures data is written to disk (flushes buffer)
#
# Frees up system resources
#
# Prevents file corruption
#
# Done automatically when using the with statement
#
# **Q20. What is the difference between `file.read()` and `file.readline()` in Python?**
#
# file.read() – Reads the entire file content as one string
#
# file.readline() – Reads one line at a time
# Useful when dealing with large files where you may not want to load everything into memory.
#
# **Q21. What is the logging module in Python used for?**
#
# The logging module is used to record messages about a program’s execution. It's a powerful way to track:
#
# Errors
#
# Warnings
#
# Debug info
#
# Execution flow
#
# It helps in debugging and monitoring applications, especially in production.
#
# **Q22. What is the `os` module in Python used for in file handling?**
#
# The os module provides functions to interact with the operating system, especially for:
#
# File and directory operations
#
# (os.remove(), os.rename(), os.listdir(), os.path.exists())
#
# Creating/removing directories
#
# (os.mkdir(), os.rmdir())
#
# Path manipulations
#
# (os.path.join())
#
# **Q23. What are the challenges associated with memory management in Python?**
#
# Circular references: Two or more objects referencing each other can delay garbage collection.
#
# High memory usage: Dynamic typing and abstraction layers can lead to inefficient memory use.
#
# Global Interpreter Lock (GIL): Limits true parallel execution of threads.
#
# Unreleased resources: If developers forget to close files or connections, memory/resource leaks can occur.
#
# **Q24. How do you raise an exception manually in Python?**
#
# Use the raise keyword to manually trigger an exception.
#
# age = -5
#
# if age < 0:
#
#     raise ValueError("Age cannot be negative")
#
# **Q25. Why is it important to use multithreading in certain applications?**
#
# Multithreading is useful for:
#
# I/O-bound tasks (e.g., network requests, file reads/writes)
#
# Improving responsiveness (like in GUIs)
#
# Running background tasks while keeping the main thread free
#
# Although Python's GIL limits true parallelism for CPU tasks, multithreading can still significantly improve performance in many real-world apps like web scrapers or file processors.

# %% [markdown]
# #Practical Questions

# %%
#Q1- How can you open a file for writing in Python and write a string to it?

file = open("File.txt", "w")
file.write("First Line\n")
file.write("Second Line\n")
file.close()

# %%
#Q2-  Write a Python program to read the contents of a file and print each line.

file = open ("File.txt", "r")
for i in file:
    print(i)
# Out:
# First Line
#
# Second Line

# %%
#Q3-  How would you handle a case where the file doesn't exist while trying to open it for reading?

try:
    with open("myfile.txt", "r") as f:
        print(file.read())
except FileNotFoundError:
    print("error: File is not found")
# Out:
# error: File is not found

# %%
#Q4-  Write a Python script that reads from one file and writes its content to another file.
source_file = "File.txt"
destination_file = "destinationfile.txt"

try:
    # Open the source file in read mode
    with open(source_file, 'r') as infile:
        content = infile.read()

    # Open the destination file in write mode
    with open(destination_file, 'w') as outfile:
        outfile.write(content)

    print("File copied successfully!")

except FileNotFoundError:
    print(f"Error: The file {source_file} does not exist.")

except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# File copied successfully!

# %%
#Q5-  How would you catch and handle division by zero error in Python.
try:
    4/0

except ZeroDivisionError as e:
    print("The error occurs in code", e)
# Out:
# The error occurs in code division by zero

# %%
#Q6- Write a Python program that logs an error message to a log file when a division by zero exception occurs.

import logging
logging.basicConfig(filename = "program.log", level = logging.DEBUG)
try:
    10/0
except ZeroDivisionError as e:
    logging.error(f"Division by zero occured {e}")
# Out:
# ERROR:root:Division by zero occured division by zero

# %%
#Q7- How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module.

import logging
logging.basicConfig(filename = "program1.log", level = logging.DEBUG)


logging.info("This is a info message")
logging.error("This is a error messqage")
logging.warning("This is a warning message")
# Out:
# ERROR:root:This is a error messqage
# WARNING:root:This is a warning message

# %%
#Q8-  Write a program to handle a file opening error using exception handling.

try:
    with open("new_file.txt", "r") as f:
        print(f.read())
except FileNotFoundError as e:
    print("File is not found", e)
# Out:
# File is not found [Errno 2] No such file or directory: 'new_file.txt'

# %%
#Q9-  How can you read a file line by line and store its content in a list in Python.

line = []
with open("File.txt", "r") as file:
    for i in file:
        line.append(i)

print(line)
# Out:
# ['First Line\n', 'Second Line\n']

# %%
#Q10- How can you append data to an existing file in Python.

with open("File.txt", "a") as file:
    file.write("Third Line\n")
    file.write("Fourth Line\n")

# %%
#Q11- Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.

try:
    data = {"Name":"Ajay", "Age": 25}
    data["location"]

except KeyError as e:
    print("Key is not found", e)
# Out:
# Key is not found 'location'

# %%
#Q12- Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

try:
    2/"aman"

except ZeroDivisionError:
    print("this is a zero division error")

except TypeError:
    print("this is a type error")

except Exception as e:
    print("The type of error is", e)
# Out:
# this is a type error

# %%
#Q13- How would you check if a file exists before attempting to read it in Python.

try:
    with open("File.txt", "r") as file:
        print(file.read())
        print("File Exists")
except FileNotFoundError as e:
    print("File do not exist", e)
# Out:
# First Line
# Second Line
# Third Line
# Fourth Line
#
# File Exists

# %%
#Q14- Write a program that uses the logging module to log both informational and error messages.

import logging
logging.basicConfig(filename = "program.log", level = logging.INFO, format = "%(asctime)s - %(levelname)s - %(message)s")

logging.info("This is informational message")
logging.error("This is error message")
# Out:
# ERROR:root:This is error message

# %%
#Q15- Write a Python program that prints the content of a file and handles the case when the file is empty.

try:
    with open("File.txt", "r") as file:
        content = file.read()
        if content.strip() == "":
            print("file is empty")
        else:
            print("File content:\n",content)

except FileNotFoundError as e:
    print("File is not found", e)
# Out:
# File content:
#  First Line
# Second Line
# Third Line
# Fourth Line

# %%
#Q16-  Demonstrate how to use memory profiling to check the memory usage of a small program.

# %pip install memory_profiler
# %load_ext memory_profiler
# Out:
# Requirement already satisfied: memory_profiler in /usr/local/lib/python3.11/dist-packages (0.61.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from memory_profiler) (5.9.5)
# The memory_profiler extension is already loaded. To reload it, use:
#   %reload_ext memory_profiler

# %%
def test_memory():
    a = [i*2 for i in range(10000000)]
    return a

# %memit test_memory()
# Out:
# peak memory: 752.52 MiB, increment: 313.42 MiB

# %%
#Q17- Write a Python program to create and write a list of numbers to a file, one number per line.

data = [2,5,8,4,2,9,45,34,23]

with open("list_file.txt", "w") as file:
    for i in data:
        file.write(str(i) + "\n")

# %%
#Q18- How would you implement a basic logging setup that logs to a file with rotation after 1MB.

import logging
from logging.handlers import RotatingFileHandler

logger = logging.getLogger("my_logger")
logger.setLevel(logging.INFO)

handler = RotatingFileHandler(filename = "my_log.log", maxBytes= 1*1024*1024, backupCount= 3)

formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
handler.setFormatter(formatter)

logger.addHandler(handler)

for i in range(1000):
    logger.info(f"This is log entry number {i}")
# Out:
# INFO:my_logger:This is log entry number 0
# INFO:my_logger:This is log entry number 1
# INFO:my_logger:This is log entry number 2
# INFO:my_logger:This is log entry number 3
# INFO:my_logger:This is log entry number 4
# INFO:my_logger:This is log entry number 5
# INFO:my_logger:This is log entry number 6
# INFO:my_logger:This is log entry number 7
# INFO:my_logger:This is log entry number 8
# INFO:my_logger:This is log entry number 9
# INFO:my_logger:This is log entry number 10
# INFO:my_logger:This is log entry number 11
# INFO:my_logger:This is log entry number 12
# INFO:my_logger:This is log entry number 13
# INFO:my_logger:This is log entry number 14
# INFO:my_logger:This is log entry number 15
# INFO:my_logger:This is log entry number 16
# INFO:my_logger:This is log entry number 17
# INFO:my_logger:This is log entry number 18
# INFO:my_logger:This is log entry number 19
# INFO:my_logger:This is log entry number 20
# INFO:my_logger:This is log entry number 21
# INFO:my_logger:This is log entry number 22
# INFO:my_logger:This is log entry number 23
# INFO:my_logger:This is log entry number 24
# INFO:my_logger:This is log entry number 25
# INFO:my_logger:This is log entry number 26
# INFO:my_logger:This is log entry number 27
# INFO:my_logger:This is log entry number 28
# INFO:my_logger:This is log entry number 29
# INFO:my_logger:This is log entry number 30
# INFO:my_logger:This is log entry number 31
# INFO:my_logger:This is log entry number 32
# INFO:my_logger:This is log entry number 33
# INFO:my_logger:This is log entry number 34
# INFO:my_logger:This is log entry number 35
# INFO:my_logger:This is log entry number 36
# INFO:my_logger:This is log entry number 37
# INFO:my_logger:This is log entry number 38
# INFO:my_logger:This is log entry number 39
# INFO:my_logger:This is log entry number 40
# INFO:my_logger:This is log entry number 41
# INFO:my_logger:This is log entry number 42
# INFO:my_logger:This is log entry number 43
# INFO:my_logger:This is log entry number 44
# INFO:my_logger:This is log entry number 45
# INFO:my_logger:This is log entry number 46
# INFO:my_logger:This is log entry number 47
# INFO:my_logger:This is log entry number 48
# INFO:my_logger:This is log entry number 49
# INFO:my_logger:This is log entry number 50
# INFO:my_logger:This is log entry number 51
# INFO:my_logger:This is log entry number 52
# INFO:my_logger:This is log entry number 53
# INFO:my_logger:This is log entry number 54
# INFO:my_logger:This is log entry number 55
# INFO:my_logger:This is log entry number 56
# INFO:my_logger:This is log entry number 57
# INFO:my_logger:This is log entry number 58
# INFO:my_logger:This is log entry number 59
# INFO:my_logger:This is log entry number 60
# INFO:my_logger:This is log entry number 61
# INFO:my_logger:This is log entry number 62
# INFO:my_logger:This is log entry number 63
# INFO:my_logger:This is log entry number 64
# INFO:my_logger:This is log entry number 65
# INFO:my_logger:This is log entry number 66
# INFO:my_logger:This is log entry number 67
# INFO:my_logger:This is log entry number 68
# INFO:my_logger:This is log entry number 69
# INFO:my_logger:This is log entry number 70
# INFO:my_logger:This is log entry number 71
# INFO:my_logger:This is log entry number 72
# INFO:my_logger:This is log entry number 73
# INFO:my_logger:This is log entry number 74
# INFO:my_logger:This is log entry number 75
# INFO:my_logger:This is log entry number 76
# INFO:my_logger:This is log entry number 77
# INFO:my_logger:This is log entry number 78
# INFO:my_logger:This is log entry number 79
# INFO:my_logger:This is log entry number 80
# INFO:my_logger:This is log entry number 81
# INFO:my_logger:This is log entry number 82
# INFO:my_logger:This is log entry number 83
# INFO:my_logger:This is log entry number 84
# INFO:my_logger:This is log entry number 85
# INFO:my_logger:This is log entry number 86
# INFO:my_logger:This is log entry number 87
# INFO:my_logger:This is log entry number 88
# INFO:my_logger:This is log entry number 89
# INFO:my_logger:This is log entry number 90
# INFO:my_logger:This is log entry number 91
# INFO:my_logger:This is log entry number 92
# INFO:my_logger:This is log entry number 93
# INFO:my_logger:This is log entry number 94
# INFO:my_logger:This is log entry number 95
# INFO:my_logger:This is log entry number 96
# INFO:my_logger:This is log entry number 97
# INFO:my_logger:This is log entry number 98
# INFO:my_logger:This is log entry number 99
# INFO:my_logger:This is log entry number 100
# INFO:my_logger:This is log entry number 101
# INFO:my_logger:This is log entry number 102
# INFO:my_logger:This is log entry number 103
# INFO:my_logger:This is log entry number 104
# INFO:my_logger:This is log entry number 105
# INFO:my_logger:This is log entry number 106
# INFO:my_logger:This is log entry number 107
# INFO:my_logger:This is log entry number 108
# INFO:my_logger:This is log entry number 109
# INFO:my_logger:This is log entry number 110
# INFO:my_logger:This is log entry number 111
# INFO:my_logger:This is log entry number 112
# INFO:my_logger:This is log entry number 113
# INFO:my_logger:This is log entry number 114
# INFO:my_logger:This is log entry number 115
# INFO:my_logger:This is log entry number 116
# INFO:my_logger:This is log entry number 117
# INFO:my_logger:This is log entry number 118
# INFO:my_logger:This is log entry number 119
# INFO:my_logger:This is log entry number 120
# INFO:my_logger:This is log entry number 121
# INFO:my_logger:This is log entry number 122
# INFO:my_logger:This is log entry number 123
# INFO:my_logger:This is log entry number 124
# INFO:my_logger:This is log entry number 125
# INFO:my_logger:This is log entry number 126
# INFO:my_logger:This is log entry number 127
# INFO:my_logger:This is log entry number 128
# INFO:my_logger:This is log entry number 129
# INFO:my_logger:This is log entry number 130
# INFO:my_logger:This is log entry number 131
# INFO:my_logger:This is log entry number 132
# INFO:my_logger:This is log entry number 133
# INFO:my_logger:This is log entry number 134
# INFO:my_logger:This is log entry number 135
# INFO:my_logger:This is log entry number 136
# INFO:my_logger:This is log entry number 137
# INFO:my_logger:This is log entry number 138
# INFO:my_logger:This is log entry number 139
# INFO:my_logger:This is log entry number 140
# INFO:my_logger:This is log entry number 141
# INFO:my_logger:This is log entry number 142
# INFO:my_logger:This is log entry number 143
# INFO:my_logger:This is log entry number 144
# INFO:my_logger:This is log entry number 145
# INFO:my_logger:This is log entry number 146
# INFO:my_logger:This is log entry number 147
# INFO:my_logger:This is log entry number 148
# INFO:my_logger:This is log entry number 149
# INFO:my_logger:This is log entry number 150
# INFO:my_logger:This is log entry number 151
# INFO:my_logger:This is log entry number 152
# INFO:my_logger:This is log entry number 153
# INFO:my_logger:This is log entry number 154
# INFO:my_logger:This is log entry number 155
# INFO:my_logger:This is log entry number 156
# INFO:my_logger:This is log entry number 157
# INFO:my_logger:This is log entry number 158
# INFO:my_logger:This is log entry number 159
# INFO:my_logger:This is log entry number 160
# INFO:my_logger:This is log entry number 161
# INFO:my_logger:This is log entry number 162
# INFO:my_logger:This is log entry number 163
# INFO:my_logger:This is log entry number 164
# INFO:my_logger:This is log entry number 165
# INFO:my_logger:This is log entry number 166
# INFO:my_logger:This is log entry number 167
# INFO:my_logger:This is log entry number 168
# INFO:my_logger:This is log entry number 169
# INFO:my_logger:This is log entry number 170
# INFO:my_logger:This is log entry number 171
# INFO:my_logger:This is log entry number 172
# INFO:my_logger:This is log entry number 173
# INFO:my_logger:This is log entry number 174
# INFO:my_logger:This is log entry number 175
# INFO:my_logger:This is log entry number 176
# INFO:my_logger:This is log entry number 177
# INFO:my_logger:This is log entry number 178
# INFO:my_logger:This is log entry number 179
# INFO:my_logger:This is log entry number 180
# INFO:my_logger:This is log entry number 181
# INFO:my_logger:This is log entry number 182
# INFO:my_logger:This is log entry number 183
# INFO:my_logger:This is log entry number 184
# INFO:my_logger:This is log entry number 185
# INFO:my_logger:This is log entry number 186
# INFO:my_logger:This is log entry number 187
# INFO:my_logger:This is log entry number 188
# INFO:my_logger:This is log entry number 189
# INFO:my_logger:This is log entry number 190
# INFO:my_logger:This is log entry number 191
# INFO:my_logger:This is log entry number 192
# INFO:my_logger:This is log entry number 193
# INFO:my_logger:This is log entry number 194
# INFO:my_logger:This is log entry number 195
# INFO:my_logger:This is log entry number 196
# INFO:my_logger:This is log entry number 197
# INFO:my_logger:This is log entry number 198
# INFO:my_logger:This is log entry number 199
# INFO:my_logger:This is log entry number 200
# INFO:my_logger:This is log entry number 201
# INFO:my_logger:This is log entry number 202
# INFO:my_logger:This is log entry number 203
# INFO:my_logger:This is log entry number 204
# INFO:my_logger:This is log entry number 205
# INFO:my_logger:This is log entry number 206
# INFO:my_logger:This is log entry number 207
# INFO:my_logger:This is log entry number 208
# INFO:my_logger:This is log entry number 209
# INFO:my_logger:This is log entry number 210
# INFO:my_logger:This is log entry number 211
# INFO:my_logger:This is log entry number 212
# INFO:my_logger:This is log entry number 213
# INFO:my_logger:This is log entry number 214
# INFO:my_logger:This is log entry number 215
# INFO:my_logger:This is log entry number 216
# INFO:my_logger:This is log entry number 217
# INFO:my_logger:This is log entry number 218
# INFO:my_logger:This is log entry number 219
# INFO:my_logger:This is log entry number 220
# INFO:my_logger:This is log entry number 221
# INFO:my_logger:This is log entry number 222
# INFO:my_logger:This is log entry number 223
# INFO:my_logger:This is log entry number 224
# INFO:my_logger:This is log entry number 225
# INFO:my_logger:This is log entry number 226
# INFO:my_logger:This is log entry number 227
# INFO:my_logger:This is log entry number 228
# INFO:my_logger:This is log entry number 229
# INFO:my_logger:This is log entry number 230
# INFO:my_logger:This is log entry number 231
# INFO:my_logger:This is log entry number 232
# INFO:my_logger:This is log entry number 233
# INFO:my_logger:This is log entry number 234
# INFO:my_logger:This is log entry number 235
# INFO:my_logger:This is log entry number 236
# INFO:my_logger:This is log entry number 237
# INFO:my_logger:This is log entry number 238
# INFO:my_logger:This is log entry number 239
# INFO:my_logger:This is log entry number 240
# INFO:my_logger:This is log entry number 241
# INFO:my_logger:This is log entry number 242
# INFO:my_logger:This is log entry number 243
# INFO:my_logger:This is log entry number 244
# INFO:my_logger:This is log entry number 245
# INFO:my_logger:This is log entry number 246
# INFO:my_logger:This is log entry number 247
# INFO:my_logger:This is log entry number 248
# INFO:my_logger:This is log entry number 249
# INFO:my_logger:This is log entry number 250
# INFO:my_logger:This is log entry number 251
# INFO:my_logger:This is log entry number 252
# INFO:my_logger:This is log entry number 253
# INFO:my_logger:This is log entry number 254
# INFO:my_logger:This is log entry number 255
# INFO:my_logger:This is log entry number 256
# INFO:my_logger:This is log entry number 257
# INFO:my_logger:This is log entry number 258
# INFO:my_logger:This is log entry number 259
# INFO:my_logger:This is log entry number 260
# INFO:my_logger:This is log entry number 261
# INFO:my_logger:This is log entry number 262
# INFO:my_logger:This is log entry number 263
# INFO:my_logger:This is log entry number 264
# INFO:my_logger:This is log entry number 265
# INFO:my_logger:This is log entry number 266
# INFO:my_logger:This is log entry number 267
# INFO:my_logger:This is log entry number 268
# INFO:my_logger:This is log entry number 269
# INFO:my_logger:This is log entry number 270
# INFO:my_logger:This is log entry number 271
# INFO:my_logger:This is log entry number 272
# INFO:my_logger:This is log entry number 273
# INFO:my_logger:This is log entry number 274
# INFO:my_logger:This is log entry number 275
# INFO:my_logger:This is log entry number 276
# INFO:my_logger:This is log entry number 277
# INFO:my_logger:This is log entry number 278
# INFO:my_logger:This is log entry number 279
# INFO:my_logger:This is log entry number 280
# INFO:my_logger:This is log entry number 281
# INFO:my_logger:This is log entry number 282
# INFO:my_logger:This is log entry number 283
# INFO:my_logger:This is log entry number 284
# INFO:my_logger:This is log entry number 285
# INFO:my_logger:This is log entry number 286
# INFO:my_logger:This is log entry number 287
# INFO:my_logger:This is log entry number 288
# INFO:my_logger:This is log entry number 289
# INFO:my_logger:This is log entry number 290
# INFO:my_logger:This is log entry number 291
# INFO:my_logger:This is log entry number 292
# INFO:my_logger:This is log entry number 293
# INFO:my_logger:This is log entry number 294
# INFO:my_logger:This is log entry number 295
# INFO:my_logger:This is log entry number 296
# INFO:my_logger:This is log entry number 297
# INFO:my_logger:This is log entry number 298
# INFO:my_logger:This is log entry number 299
# INFO:my_logger:This is log entry number 300
# INFO:my_logger:This is log entry number 301
# INFO:my_logger:This is log entry number 302
# INFO:my_logger:This is log entry number 303
# INFO:my_logger:This is log entry number 304
# INFO:my_logger:This is log entry number 305
# INFO:my_logger:This is log entry number 306
# INFO:my_logger:This is log entry number 307
# INFO:my_logger:This is log entry number 308
# INFO:my_logger:This is log entry number 309
# INFO:my_logger:This is log entry number 310
# INFO:my_logger:This is log entry number 311
# INFO:my_logger:This is log entry number 312
# INFO:my_logger:This is log entry number 313
# INFO:my_logger:This is log entry number 314
# INFO:my_logger:This is log entry number 315
# INFO:my_logger:This is log entry number 316
# INFO:my_logger:This is log entry number 317
# INFO:my_logger:This is log entry number 318
# INFO:my_logger:This is log entry number 319
# INFO:my_logger:This is log entry number 320
# INFO:my_logger:This is log entry number 321
# INFO:my_logger:This is log entry number 322
# INFO:my_logger:This is log entry number 323
# INFO:my_logger:This is log entry number 324
# INFO:my_logger:This is log entry number 325
# INFO:my_logger:This is log entry number 326
# INFO:my_logger:This is log entry number 327
# INFO:my_logger:This is log entry number 328
# INFO:my_logger:This is log entry number 329
# INFO:my_logger:This is log entry number 330
# INFO:my_logger:This is log entry number 331
# INFO:my_logger:This is log entry number 332
# INFO:my_logger:This is log entry number 333
# INFO:my_logger:This is log entry number 334
# INFO:my_logger:This is log entry number 335
# INFO:my_logger:This is log entry number 336
# INFO:my_logger:This is log entry number 337
# INFO:my_logger:This is log entry number 338
# INFO:my_logger:This is log entry number 339
# INFO:my_logger:This is log entry number 340
# INFO:my_logger:This is log entry number 341
# INFO:my_logger:This is log entry number 342
# INFO:my_logger:This is log entry number 343
# INFO:my_logger:This is log entry number 344
# INFO:my_logger:This is log entry number 345
# INFO:my_logger:This is log entry number 346
# INFO:my_logger:This is log entry number 347
# INFO:my_logger:This is log entry number 348
# INFO:my_logger:This is log entry number 349
# INFO:my_logger:This is log entry number 350
# INFO:my_logger:This is log entry number 351
# INFO:my_logger:This is log entry number 352
# INFO:my_logger:This is log entry number 353
# INFO:my_logger:This is log entry number 354
# INFO:my_logger:This is log entry number 355
# INFO:my_logger:This is log entry number 356
# INFO:my_logger:This is log entry number 357
# INFO:my_logger:This is log entry number 358
# INFO:my_logger:This is log entry number 359
# INFO:my_logger:This is log entry number 360
# INFO:my_logger:This is log entry number 361
# INFO:my_logger:This is log entry number 362
# INFO:my_logger:This is log entry number 363
# INFO:my_logger:This is log entry number 364
# INFO:my_logger:This is log entry number 365
# INFO:my_logger:This is log entry number 366
# INFO:my_logger:This is log entry number 367
# INFO:my_logger:This is log entry number 368
# INFO:my_logger:This is log entry number 369
# INFO:my_logger:This is log entry number 370
# INFO:my_logger:This is log entry number 371
# INFO:my_logger:This is log entry number 372
# INFO:my_logger:This is log entry number 373
# INFO:my_logger:This is log entry number 374
# INFO:my_logger:This is log entry number 375
# INFO:my_logger:This is log entry number 376
# INFO:my_logger:This is log entry number 377
# INFO:my_logger:This is log entry number 378
# INFO:my_logger:This is log entry number 379
# INFO:my_logger:This is log entry number 380
# INFO:my_logger:This is log entry number 381
# INFO:my_logger:This is log entry number 382
# INFO:my_logger:This is log entry number 383
# INFO:my_logger:This is log entry number 384
# INFO:my_logger:This is log entry number 385
# INFO:my_logger:This is log entry number 386
# INFO:my_logger:This is log entry number 387
# INFO:my_logger:This is log entry number 388
# INFO:my_logger:This is log entry number 389
# INFO:my_logger:This is log entry number 390
# INFO:my_logger:This is log entry number 391
# INFO:my_logger:This is log entry number 392
# INFO:my_logger:This is log entry number 393
# INFO:my_logger:This is log entry number 394
# INFO:my_logger:This is log entry number 395
# INFO:my_logger:This is log entry number 396
# INFO:my_logger:This is log entry number 397
# INFO:my_logger:This is log entry number 398
# INFO:my_logger:This is log entry number 399
# INFO:my_logger:This is log entry number 400
# INFO:my_logger:This is log entry number 401
# INFO:my_logger:This is log entry number 402
# INFO:my_logger:This is log entry number 403
# INFO:my_logger:This is log entry number 404
# INFO:my_logger:This is log entry number 405
# INFO:my_logger:This is log entry number 406
# INFO:my_logger:This is log entry number 407
# INFO:my_logger:This is log entry number 408
# INFO:my_logger:This is log entry number 409
# INFO:my_logger:This is log entry number 410
# INFO:my_logger:This is log entry number 411
# INFO:my_logger:This is log entry number 412
# INFO:my_logger:This is log entry number 413
# INFO:my_logger:This is log entry number 414
# INFO:my_logger:This is log entry number 415
# INFO:my_logger:This is log entry number 416
# INFO:my_logger:This is log entry number 417
# INFO:my_logger:This is log entry number 418
# INFO:my_logger:This is log entry number 419
# INFO:my_logger:This is log entry number 420
# INFO:my_logger:This is log entry number 421
# INFO:my_logger:This is log entry number 422
# INFO:my_logger:This is log entry number 423
# INFO:my_logger:This is log entry number 424
# INFO:my_logger:This is log entry number 425
# INFO:my_logger:This is log entry number 426
# INFO:my_logger:This is log entry number 427
# INFO:my_logger:This is log entry number 428
# INFO:my_logger:This is log entry number 429
# INFO:my_logger:This is log entry number 430
# INFO:my_logger:This is log entry number 431
# INFO:my_logger:This is log entry number 432
# INFO:my_logger:This is log entry number 433
# INFO:my_logger:This is log entry number 434
# INFO:my_logger:This is log entry number 435
# INFO:my_logger:This is log entry number 436
# INFO:my_logger:This is log entry number 437
# INFO:my_logger:This is log entry number 438
# INFO:my_logger:This is log entry number 439
# INFO:my_logger:This is log entry number 440
# INFO:my_logger:This is log entry number 441
# INFO:my_logger:This is log entry number 442
# INFO:my_logger:This is log entry number 443
# INFO:my_logger:This is log entry number 444
# INFO:my_logger:This is log entry number 445
# INFO:my_logger:This is log entry number 446
# INFO:my_logger:This is log entry number 447
# INFO:my_logger:This is log entry number 448
# INFO:my_logger:This is log entry number 449
# INFO:my_logger:This is log entry number 450
# INFO:my_logger:This is log entry number 451
# INFO:my_logger:This is log entry number 452
# INFO:my_logger:This is log entry number 453
# INFO:my_logger:This is log entry number 454
# INFO:my_logger:This is log entry number 455
# INFO:my_logger:This is log entry number 456
# INFO:my_logger:This is log entry number 457
# INFO:my_logger:This is log entry number 458
# INFO:my_logger:This is log entry number 459
# INFO:my_logger:This is log entry number 460
# INFO:my_logger:This is log entry number 461
# INFO:my_logger:This is log entry number 462
# INFO:my_logger:This is log entry number 463
# INFO:my_logger:This is log entry number 464
# INFO:my_logger:This is log entry number 465
# INFO:my_logger:This is log entry number 466
# INFO:my_logger:This is log entry number 467
# INFO:my_logger:This is log entry number 468
# INFO:my_logger:This is log entry number 469
# INFO:my_logger:This is log entry number 470
# INFO:my_logger:This is log entry number 471
# INFO:my_logger:This is log entry number 472
# INFO:my_logger:This is log entry number 473
# INFO:my_logger:This is log entry number 474
# INFO:my_logger:This is log entry number 475
# INFO:my_logger:This is log entry number 476
# INFO:my_logger:This is log entry number 477
# INFO:my_logger:This is log entry number 478
# INFO:my_logger:This is log entry number 479
# INFO:my_logger:This is log entry number 480
# INFO:my_logger:This is log entry number 481
# INFO:my_logger:This is log entry number 482
# INFO:my_logger:This is log entry number 483
# INFO:my_logger:This is log entry number 484
# INFO:my_logger:This is log entry number 485
# INFO:my_logger:This is log entry number 486
# INFO:my_logger:This is log entry number 487
# INFO:my_logger:This is log entry number 488
# INFO:my_logger:This is log entry number 489
# INFO:my_logger:This is log entry number 490
# INFO:my_logger:This is log entry number 491
# INFO:my_logger:This is log entry number 492
# INFO:my_logger:This is log entry number 493
# INFO:my_logger:This is log entry number 494
# INFO:my_logger:This is log entry number 495
# INFO:my_logger:This is log entry number 496
# INFO:my_logger:This is log entry number 497
# INFO:my_logger:This is log entry number 498
# INFO:my_logger:This is log entry number 499
# INFO:my_logger:This is log entry number 500
# INFO:my_logger:This is log entry number 501
# INFO:my_logger:This is log entry number 502
# INFO:my_logger:This is log entry number 503
# INFO:my_logger:This is log entry number 504
# INFO:my_logger:This is log entry number 505
# INFO:my_logger:This is log entry number 506
# INFO:my_logger:This is log entry number 507
# INFO:my_logger:This is log entry number 508
# INFO:my_logger:This is log entry number 509
# INFO:my_logger:This is log entry number 510
# INFO:my_logger:This is log entry number 511
# INFO:my_logger:This is log entry number 512
# INFO:my_logger:This is log entry number 513
# INFO:my_logger:This is log entry number 514
# INFO:my_logger:This is log entry number 515
# INFO:my_logger:This is log entry number 516
# INFO:my_logger:This is log entry number 517
# INFO:my_logger:This is log entry number 518
# INFO:my_logger:This is log entry number 519
# INFO:my_logger:This is log entry number 520
# INFO:my_logger:This is log entry number 521
# INFO:my_logger:This is log entry number 522
# INFO:my_logger:This is log entry number 523
# INFO:my_logger:This is log entry number 524
# INFO:my_logger:This is log entry number 525
# INFO:my_logger:This is log entry number 526
# INFO:my_logger:This is log entry number 527
# INFO:my_logger:This is log entry number 528
# INFO:my_logger:This is log entry number 529
# INFO:my_logger:This is log entry number 530
# INFO:my_logger:This is log entry number 531
# INFO:my_logger:This is log entry number 532
# INFO:my_logger:This is log entry number 533
# INFO:my_logger:This is log entry number 534
# INFO:my_logger:This is log entry number 535
# INFO:my_logger:This is log entry number 536
# INFO:my_logger:This is log entry number 537
# INFO:my_logger:This is log entry number 538
# INFO:my_logger:This is log entry number 539
# INFO:my_logger:This is log entry number 540
# INFO:my_logger:This is log entry number 541
# INFO:my_logger:This is log entry number 542
# INFO:my_logger:This is log entry number 543
# INFO:my_logger:This is log entry number 544
# INFO:my_logger:This is log entry number 545
# INFO:my_logger:This is log entry number 546
# INFO:my_logger:This is log entry number 547
# INFO:my_logger:This is log entry number 548
# INFO:my_logger:This is log entry number 549
# INFO:my_logger:This is log entry number 550
# INFO:my_logger:This is log entry number 551
# INFO:my_logger:This is log entry number 552
# INFO:my_logger:This is log entry number 553
# INFO:my_logger:This is log entry number 554
# INFO:my_logger:This is log entry number 555
# INFO:my_logger:This is log entry number 556
# INFO:my_logger:This is log entry number 557
# INFO:my_logger:This is log entry number 558
# INFO:my_logger:This is log entry number 559
# INFO:my_logger:This is log entry number 560
# INFO:my_logger:This is log entry number 561
# INFO:my_logger:This is log entry number 562
# INFO:my_logger:This is log entry number 563
# INFO:my_logger:This is log entry number 564
# INFO:my_logger:This is log entry number 565
# INFO:my_logger:This is log entry number 566
# INFO:my_logger:This is log entry number 567
# INFO:my_logger:This is log entry number 568
# INFO:my_logger:This is log entry number 569
# INFO:my_logger:This is log entry number 570
# INFO:my_logger:This is log entry number 571
# INFO:my_logger:This is log entry number 572
# INFO:my_logger:This is log entry number 573
# INFO:my_logger:This is log entry number 574
# INFO:my_logger:This is log entry number 575
# INFO:my_logger:This is log entry number 576
# INFO:my_logger:This is log entry number 577
# INFO:my_logger:This is log entry number 578
# INFO:my_logger:This is log entry number 579
# INFO:my_logger:This is log entry number 580
# INFO:my_logger:This is log entry number 581
# INFO:my_logger:This is log entry number 582
# INFO:my_logger:This is log entry number 583
# INFO:my_logger:This is log entry number 584
# INFO:my_logger:This is log entry number 585
# INFO:my_logger:This is log entry number 586
# INFO:my_logger:This is log entry number 587
# INFO:my_logger:This is log entry number 588
# INFO:my_logger:This is log entry number 589
# INFO:my_logger:This is log entry number 590
# INFO:my_logger:This is log entry number 591
# INFO:my_logger:This is log entry number 592
# INFO:my_logger:This is log entry number 593
# INFO:my_logger:This is log entry number 594
# INFO:my_logger:This is log entry number 595
# INFO:my_logger:This is log entry number 596
# INFO:my_logger:This is log entry number 597
# INFO:my_logger:This is log entry number 598
# INFO:my_logger:This is log entry number 599
# INFO:my_logger:This is log entry number 600
# INFO:my_logger:This is log entry number 601
# INFO:my_logger:This is log entry number 602
# INFO:my_logger:This is log entry number 603
# INFO:my_logger:This is log entry number 604
# INFO:my_logger:This is log entry number 605
# INFO:my_logger:This is log entry number 606
# INFO:my_logger:This is log entry number 607
# INFO:my_logger:This is log entry number 608
# INFO:my_logger:This is log entry number 609
# INFO:my_logger:This is log entry number 610
# INFO:my_logger:This is log entry number 611
# INFO:my_logger:This is log entry number 612
# INFO:my_logger:This is log entry number 613
# INFO:my_logger:This is log entry number 614
# INFO:my_logger:This is log entry number 615
# INFO:my_logger:This is log entry number 616
# INFO:my_logger:This is log entry number 617
# INFO:my_logger:This is log entry number 618
# INFO:my_logger:This is log entry number 619
# INFO:my_logger:This is log entry number 620
# INFO:my_logger:This is log entry number 621
# INFO:my_logger:This is log entry number 622
# INFO:my_logger:This is log entry number 623
# INFO:my_logger:This is log entry number 624
# INFO:my_logger:This is log entry number 625
# INFO:my_logger:This is log entry number 626
# INFO:my_logger:This is log entry number 627
# INFO:my_logger:This is log entry number 628
# INFO:my_logger:This is log entry number 629
# INFO:my_logger:This is log entry number 630
# INFO:my_logger:This is log entry number 631
# INFO:my_logger:This is log entry number 632
# INFO:my_logger:This is log entry number 633
# INFO:my_logger:This is log entry number 634
# INFO:my_logger:This is log entry number 635
# INFO:my_logger:This is log entry number 636
# INFO:my_logger:This is log entry number 637
# INFO:my_logger:This is log entry number 638
# INFO:my_logger:This is log entry number 639
# INFO:my_logger:This is log entry number 640
# INFO:my_logger:This is log entry number 641
# INFO:my_logger:This is log entry number 642
# INFO:my_logger:This is log entry number 643
# INFO:my_logger:This is log entry number 644
# INFO:my_logger:This is log entry number 645
# INFO:my_logger:This is log entry number 646
# INFO:my_logger:This is log entry number 647
# INFO:my_logger:This is log entry number 648
# INFO:my_logger:This is log entry number 649
# INFO:my_logger:This is log entry number 650
# INFO:my_logger:This is log entry number 651
# INFO:my_logger:This is log entry number 652
# INFO:my_logger:This is log entry number 653
# INFO:my_logger:This is log entry number 654
# INFO:my_logger:This is log entry number 655
# INFO:my_logger:This is log entry number 656
# INFO:my_logger:This is log entry number 657
# INFO:my_logger:This is log entry number 658
# INFO:my_logger:This is log entry number 659
# INFO:my_logger:This is log entry number 660
# INFO:my_logger:This is log entry number 661
# INFO:my_logger:This is log entry number 662
# INFO:my_logger:This is log entry number 663
# INFO:my_logger:This is log entry number 664
# INFO:my_logger:This is log entry number 665
# INFO:my_logger:This is log entry number 666
# INFO:my_logger:This is log entry number 667
# INFO:my_logger:This is log entry number 668
# INFO:my_logger:This is log entry number 669
# INFO:my_logger:This is log entry number 670
# INFO:my_logger:This is log entry number 671
# INFO:my_logger:This is log entry number 672
# INFO:my_logger:This is log entry number 673
# INFO:my_logger:This is log entry number 674
# INFO:my_logger:This is log entry number 675
# INFO:my_logger:This is log entry number 676
# INFO:my_logger:This is log entry number 677
# INFO:my_logger:This is log entry number 678
# INFO:my_logger:This is log entry number 679
# INFO:my_logger:This is log entry number 680
# INFO:my_logger:This is log entry number 681
# INFO:my_logger:This is log entry number 682
# INFO:my_logger:This is log entry number 683
# INFO:my_logger:This is log entry number 684
# INFO:my_logger:This is log entry number 685
# INFO:my_logger:This is log entry number 686
# INFO:my_logger:This is log entry number 687
# INFO:my_logger:This is log entry number 688
# INFO:my_logger:This is log entry number 689
# INFO:my_logger:This is log entry number 690
# INFO:my_logger:This is log entry number 691
# INFO:my_logger:This is log entry number 692
# INFO:my_logger:This is log entry number 693
# INFO:my_logger:This is log entry number 694
# INFO:my_logger:This is log entry number 695
# INFO:my_logger:This is log entry number 696
# INFO:my_logger:This is log entry number 697
# INFO:my_logger:This is log entry number 698
# INFO:my_logger:This is log entry number 699
# INFO:my_logger:This is log entry number 700
# INFO:my_logger:This is log entry number 701
# INFO:my_logger:This is log entry number 702
# INFO:my_logger:This is log entry number 703
# INFO:my_logger:This is log entry number 704
# INFO:my_logger:This is log entry number 705
# INFO:my_logger:This is log entry number 706
# INFO:my_logger:This is log entry number 707
# INFO:my_logger:This is log entry number 708
# INFO:my_logger:This is log entry number 709
# INFO:my_logger:This is log entry number 710
# INFO:my_logger:This is log entry number 711
# INFO:my_logger:This is log entry number 712
# INFO:my_logger:This is log entry number 713
# INFO:my_logger:This is log entry number 714
# INFO:my_logger:This is log entry number 715
# INFO:my_logger:This is log entry number 716
# INFO:my_logger:This is log entry number 717
# INFO:my_logger:This is log entry number 718
# INFO:my_logger:This is log entry number 719
# INFO:my_logger:This is log entry number 720
# INFO:my_logger:This is log entry number 721
# INFO:my_logger:This is log entry number 722
# INFO:my_logger:This is log entry number 723
# INFO:my_logger:This is log entry number 724
# INFO:my_logger:This is log entry number 725
# INFO:my_logger:This is log entry number 726
# INFO:my_logger:This is log entry number 727
# INFO:my_logger:This is log entry number 728
# INFO:my_logger:This is log entry number 729
# INFO:my_logger:This is log entry number 730
# INFO:my_logger:This is log entry number 731
# INFO:my_logger:This is log entry number 732
# INFO:my_logger:This is log entry number 733
# INFO:my_logger:This is log entry number 734
# INFO:my_logger:This is log entry number 735
# INFO:my_logger:This is log entry number 736
# INFO:my_logger:This is log entry number 737
# INFO:my_logger:This is log entry number 738
# INFO:my_logger:This is log entry number 739
# INFO:my_logger:This is log entry number 740
# INFO:my_logger:This is log entry number 741
# INFO:my_logger:This is log entry number 742
# INFO:my_logger:This is log entry number 743
# INFO:my_logger:This is log entry number 744
# INFO:my_logger:This is log entry number 745
# INFO:my_logger:This is log entry number 746
# INFO:my_logger:This is log entry number 747
# INFO:my_logger:This is log entry number 748
# INFO:my_logger:This is log entry number 749
# INFO:my_logger:This is log entry number 750
# INFO:my_logger:This is log entry number 751
# INFO:my_logger:This is log entry number 752
# INFO:my_logger:This is log entry number 753
# INFO:my_logger:This is log entry number 754
# INFO:my_logger:This is log entry number 755
# INFO:my_logger:This is log entry number 756
# INFO:my_logger:This is log entry number 757
# INFO:my_logger:This is log entry number 758
# INFO:my_logger:This is log entry number 759
# INFO:my_logger:This is log entry number 760
# INFO:my_logger:This is log entry number 761
# INFO:my_logger:This is log entry number 762
# INFO:my_logger:This is log entry number 763
# INFO:my_logger:This is log entry number 764
# INFO:my_logger:This is log entry number 765
# INFO:my_logger:This is log entry number 766
# INFO:my_logger:This is log entry number 767
# INFO:my_logger:This is log entry number 768
# INFO:my_logger:This is log entry number 769
# INFO:my_logger:This is log entry number 770
# INFO:my_logger:This is log entry number 771
# INFO:my_logger:This is log entry number 772
# INFO:my_logger:This is log entry number 773
# INFO:my_logger:This is log entry number 774
# INFO:my_logger:This is log entry number 775
# INFO:my_logger:This is log entry number 776
# INFO:my_logger:This is log entry number 777
# INFO:my_logger:This is log entry number 778
# INFO:my_logger:This is log entry number 779
# INFO:my_logger:This is log entry number 780
# INFO:my_logger:This is log entry number 781
# INFO:my_logger:This is log entry number 782
# INFO:my_logger:This is log entry number 783
# INFO:my_logger:This is log entry number 784
# INFO:my_logger:This is log entry number 785
# INFO:my_logger:This is log entry number 786
# INFO:my_logger:This is log entry number 787
# INFO:my_logger:This is log entry number 788
# INFO:my_logger:This is log entry number 789
# INFO:my_logger:This is log entry number 790
# INFO:my_logger:This is log entry number 791
# INFO:my_logger:This is log entry number 792
# INFO:my_logger:This is log entry number 793
# INFO:my_logger:This is log entry number 794
# INFO:my_logger:This is log entry number 795
# INFO:my_logger:This is log entry number 796
# INFO:my_logger:This is log entry number 797
# INFO:my_logger:This is log entry number 798
# INFO:my_logger:This is log entry number 799
# INFO:my_logger:This is log entry number 800
# INFO:my_logger:This is log entry number 801
# INFO:my_logger:This is log entry number 802
# INFO:my_logger:This is log entry number 803
# INFO:my_logger:This is log entry number 804
# INFO:my_logger:This is log entry number 805
# INFO:my_logger:This is log entry number 806
# INFO:my_logger:This is log entry number 807
# INFO:my_logger:This is log entry number 808
# INFO:my_logger:This is log entry number 809
# INFO:my_logger:This is log entry number 810
# INFO:my_logger:This is log entry number 811
# INFO:my_logger:This is log entry number 812
# INFO:my_logger:This is log entry number 813
# INFO:my_logger:This is log entry number 814
# INFO:my_logger:This is log entry number 815
# INFO:my_logger:This is log entry number 816
# INFO:my_logger:This is log entry number 817
# INFO:my_logger:This is log entry number 818
# INFO:my_logger:This is log entry number 819
# INFO:my_logger:This is log entry number 820
# INFO:my_logger:This is log entry number 821
# INFO:my_logger:This is log entry number 822
# INFO:my_logger:This is log entry number 823
# INFO:my_logger:This is log entry number 824
# INFO:my_logger:This is log entry number 825
# INFO:my_logger:This is log entry number 826
# INFO:my_logger:This is log entry number 827
# INFO:my_logger:This is log entry number 828
# INFO:my_logger:This is log entry number 829
# INFO:my_logger:This is log entry number 830
# INFO:my_logger:This is log entry number 831
# INFO:my_logger:This is log entry number 832
# INFO:my_logger:This is log entry number 833
# INFO:my_logger:This is log entry number 834
# INFO:my_logger:This is log entry number 835
# INFO:my_logger:This is log entry number 836
# INFO:my_logger:This is log entry number 837
# INFO:my_logger:This is log entry number 838
# INFO:my_logger:This is log entry number 839
# INFO:my_logger:This is log entry number 840
# INFO:my_logger:This is log entry number 841
# INFO:my_logger:This is log entry number 842
# INFO:my_logger:This is log entry number 843
# INFO:my_logger:This is log entry number 844
# INFO:my_logger:This is log entry number 845
# INFO:my_logger:This is log entry number 846
# INFO:my_logger:This is log entry number 847
# INFO:my_logger:This is log entry number 848
# INFO:my_logger:This is log entry number 849
# INFO:my_logger:This is log entry number 850
# INFO:my_logger:This is log entry number 851
# INFO:my_logger:This is log entry number 852
# INFO:my_logger:This is log entry number 853
# INFO:my_logger:This is log entry number 854
# INFO:my_logger:This is log entry number 855
# INFO:my_logger:This is log entry number 856
# INFO:my_logger:This is log entry number 857
# INFO:my_logger:This is log entry number 858
# INFO:my_logger:This is log entry number 859
# INFO:my_logger:This is log entry number 860
# INFO:my_logger:This is log entry number 861
# INFO:my_logger:This is log entry number 862
# INFO:my_logger:This is log entry number 863
# INFO:my_logger:This is log entry number 864
# INFO:my_logger:This is log entry number 865
# INFO:my_logger:This is log entry number 866
# INFO:my_logger:This is log entry number 867
# INFO:my_logger:This is log entry number 868
# INFO:my_logger:This is log entry number 869
# INFO:my_logger:This is log entry number 870
# INFO:my_logger:This is log entry number 871
# INFO:my_logger:This is log entry number 872
# INFO:my_logger:This is log entry number 873
# INFO:my_logger:This is log entry number 874
# INFO:my_logger:This is log entry number 875
# INFO:my_logger:This is log entry number 876
# INFO:my_logger:This is log entry number 877
# INFO:my_logger:This is log entry number 878
# INFO:my_logger:This is log entry number 879
# INFO:my_logger:This is log entry number 880
# INFO:my_logger:This is log entry number 881
# INFO:my_logger:This is log entry number 882
# INFO:my_logger:This is log entry number 883
# INFO:my_logger:This is log entry number 884
# INFO:my_logger:This is log entry number 885
# INFO:my_logger:This is log entry number 886
# INFO:my_logger:This is log entry number 887
# INFO:my_logger:This is log entry number 888
# INFO:my_logger:This is log entry number 889
# INFO:my_logger:This is log entry number 890
# INFO:my_logger:This is log entry number 891
# INFO:my_logger:This is log entry number 892
# INFO:my_logger:This is log entry number 893
# INFO:my_logger:This is log entry number 894
# INFO:my_logger:This is log entry number 895
# INFO:my_logger:This is log entry number 896
# INFO:my_logger:This is log entry number 897
# INFO:my_logger:This is log entry number 898
# INFO:my_logger:This is log entry number 899
# INFO:my_logger:This is log entry number 900
# INFO:my_logger:This is log entry number 901
# INFO:my_logger:This is log entry number 902
# INFO:my_logger:This is log entry number 903
# INFO:my_logger:This is log entry number 904
# INFO:my_logger:This is log entry number 905
# INFO:my_logger:This is log entry number 906
# INFO:my_logger:This is log entry number 907
# INFO:my_logger:This is log entry number 908
# INFO:my_logger:This is log entry number 909
# INFO:my_logger:This is log entry number 910
# INFO:my_logger:This is log entry number 911
# INFO:my_logger:This is log entry number 912
# INFO:my_logger:This is log entry number 913
# INFO:my_logger:This is log entry number 914
# INFO:my_logger:This is log entry number 915
# INFO:my_logger:This is log entry number 916
# INFO:my_logger:This is log entry number 917
# INFO:my_logger:This is log entry number 918
# INFO:my_logger:This is log entry number 919
# INFO:my_logger:This is log entry number 920
# INFO:my_logger:This is log entry number 921
# INFO:my_logger:This is log entry number 922
# INFO:my_logger:This is log entry number 923
# INFO:my_logger:This is log entry number 924
# INFO:my_logger:This is log entry number 925
# INFO:my_logger:This is log entry number 926
# INFO:my_logger:This is log entry number 927
# INFO:my_logger:This is log entry number 928
# INFO:my_logger:This is log entry number 929
# INFO:my_logger:This is log entry number 930
# INFO:my_logger:This is log entry number 931
# INFO:my_logger:This is log entry number 932
# INFO:my_logger:This is log entry number 933
# INFO:my_logger:This is log entry number 934
# INFO:my_logger:This is log entry number 935
# INFO:my_logger:This is log entry number 936
# INFO:my_logger:This is log entry number 937
# INFO:my_logger:This is log entry number 938
# INFO:my_logger:This is log entry number 939
# INFO:my_logger:This is log entry number 940
# INFO:my_logger:This is log entry number 941
# INFO:my_logger:This is log entry number 942
# INFO:my_logger:This is log entry number 943
# INFO:my_logger:This is log entry number 944
# INFO:my_logger:This is log entry number 945
# INFO:my_logger:This is log entry number 946
# INFO:my_logger:This is log entry number 947
# INFO:my_logger:This is log entry number 948
# INFO:my_logger:This is log entry number 949
# INFO:my_logger:This is log entry number 950
# INFO:my_logger:This is log entry number 951
# INFO:my_logger:This is log entry number 952
# INFO:my_logger:This is log entry number 953
# INFO:my_logger:This is log entry number 954
# INFO:my_logger:This is log entry number 955
# INFO:my_logger:This is log entry number 956
# INFO:my_logger:This is log entry number 957
# INFO:my_logger:This is log entry number 958
# INFO:my_logger:This is log entry number 959
# INFO:my_logger:This is log entry number 960
# INFO:my_logger:This is log entry number 961
# INFO:my_logger:This is log entry number 962
# INFO:my_logger:This is log entry number 963
# INFO:my_logger:This is log entry number 964
# INFO:my_logger:This is log entry number 965
# INFO:my_logger:This is log entry number 966
# INFO:my_logger:This is log entry number 967
# INFO:my_logger:This is log entry number 968
# INFO:my_logger:This is log entry number 969
# INFO:my_logger:This is log entry number 970
# INFO:my_logger:This is log entry number 971
# INFO:my_logger:This is log entry number 972
# INFO:my_logger:This is log entry number 973
# INFO:my_logger:This is log entry number 974
# INFO:my_logger:This is log entry number 975
# INFO:my_logger:This is log entry number 976
# INFO:my_logger:This is log entry number 977
# INFO:my_logger:This is log entry number 978
# INFO:my_logger:This is log entry number 979
# INFO:my_logger:This is log entry number 980
# INFO:my_logger:This is log entry number 981
# INFO:my_logger:This is log entry number 982
# INFO:my_logger:This is log entry number 983
# INFO:my_logger:This is log entry number 984
# INFO:my_logger:This is log entry number 985
# INFO:my_logger:This is log entry number 986
# INFO:my_logger:This is log entry number 987
# INFO:my_logger:This is log entry number 988
# INFO:my_logger:This is log entry number 989
# INFO:my_logger:This is log entry number 990
# INFO:my_logger:This is log entry number 991
# INFO:my_logger:This is log entry number 992
# INFO:my_logger:This is log entry number 993
# INFO:my_logger:This is log entry number 994
# INFO:my_logger:This is log entry number 995
# INFO:my_logger:This is log entry number 996
# INFO:my_logger:This is log entry number 997
# INFO:my_logger:This is log entry number 998
# INFO:my_logger:This is log entry number 999

# %%
#Q19- Write a program that handles both IndexError and KeyError using a try-except block.

try:
    l = [1,2,3,4]
    l[4]

except KeyError:
    print("Key error found")

except IndexError:
    print("Index error found")

except Exception as e:
    print("Type of error is", e)
# Out:
# Index error found

# %%
#Q20- How would you open a file and read its contents using a context manager in Python.

with open("File.txt", "r") as file:
    print(file.read())
# Out:
# First Line
# Second Line
# Third Line
# Fourth Line

# %%
#Q21- Write a Python program that reads a file and prints the number of occurrences of a specific word.

with open("File.txt", "r") as file:
    content = file.read().lower()

count = content.count("line".lower())

print(f"The word 'line' occurred {count} times")
# Out:
# The word 'line' occurred 4 times

# %%
#Q22- How can you check if a file is empty before attempting to read its contents.

import os

if os.path.getsize("File.txt") == 0:
    print("File is empty")
else:
    with open("File.txt", "r") as file:
        print(file.read())
# Out:
# First Line
# Second Line
# Third Line
# Fourth Line

# %%
#Q23- Write a Python program that writes to a log file when an error occurs during file handling.

import logging

logging.basicConfig(filename = "my_file.log", level = logging.ERROR, format = "%(asctime)s - %(levelname)s - %(message)s")

try:
    with open("unknown_file.txt", "r") as file:
        print(file.read())

except FileNotFoundError as e:
    logging.error(f"File not found:{e}")

except Exception as e:
    logging.error(f"Unknown error occurs:{e}")
# Out:
# ERROR:root:File not found:[Errno 2] No such file or directory: 'unknown_file.txt'
